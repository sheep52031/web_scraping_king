# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
dataStr = """ro: 0
kwop: 7
keyword: python
expansionType: area,spec,com,job,wf,wktm
order: 15
asc: 0
page: 1
mode: s
jobsource: 2018indexpoc
langFlag: 0
langStatus: 0
recommendJob: 1
hotJob: 1"""

# %%
data = {r.split(": ")[0]: r.split(": ")[1] for r in dataStr.split("\n")}

# %%
print(data)
# Out:
# {'ro': '0', 'kwop': '7', 'keyword': 'python', 'expansionType': 'area,spec,com,job,wf,wktm', 'order': '15', 'asc': '0', 'page': '1', 'mode': 's', 'jobsource': '2018indexpoc', 'langFlag': '0', 'langStatus': '0', 'recommendJob': '1', 'hotJob': '1'}

# %%
company_list = []
jobname_list = []
job_content_list = []
article_url_list = []
python_list = []
js_list = []
java_list = []
mysql_list = []
mongodb_list = []
sql_list = []
nosql_list = []

# %%
# 先抓第一頁
url = "https://www.104.com.tw/jobs/search/?ro=0&keyword=Python%20&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&area=6001001010&order=15&asc=0&page=1&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1"
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"}
res = requests.post(url, headers=headers, data=data)
soup = BeautifulSoup(res.text, 'html.parser')
# 公司名稱
company = soup.select('ul[class="b-list-inline b-clearfix"]')
# print(company)
for each_company in company:
    result = each_company.a["title"].split("：")[1].split("\n")[0]
    company_list.append(result)
print(company_list)
print(len(company_list))
# Out:
# ['億力資訊股份有限公司', '雄獅資訊科技股份有限公司', '奧米科技有限公司', '易勝資訊股份有限公司', '雙子數位科技有限公司', '岳鼎股份有限公司', '慧誠智醫股份有限公司', '禾向數位科技有限公司', '中塑油品股份有限公司', '凱文科技服務有限公司', '禾向數位科技有限公司', '飛資得資訊股份有限公司', '兆徠科技股份有限公司', '歐斯瑞有限公司', '鈦度科技有限公司', '神通資訊科技股份有限公司', '寶晶能源股份有限公司', '紐奧谷科技股份有限公司', '紐奧谷科技股份有限公司', '美商網基股份有限公司台灣分公司', '雄獅資訊科技股份有限公司', '奧米科技有限公司', '億力資訊股份有限公司', '雙子數位科技有限公司', '禾向數位科技有限公司', '易勝資訊股份有限公司', '岳鼎股份有限公司', '慧誠智醫股份有限公司', '飛資得資訊股份有限公司', '中塑油品股份有限公司', '凱文科技服務有限公司', '禾向數位科技有限公司', '兆徠科技股份有限公司', '神通資訊科技股份有限公司', '歐斯瑞有限公司', '美商網基股份有限公司台灣分公司', '鈦度科技有限公司', '紐奧谷科技股份有限公司', '寶晶能源股份有限公司', '紐奧谷科技股份有限公司']
# 40

# %%
# 職稱
article_url = soup.select('a[class="js-job-link"]')
for each_jobname in article_url:
    result = each_jobname.text
    jobname_list.append(result)
print(len(jobname_list))
# Out:
# 40

# %%
# 工作內容
job_content = soup.select('p[class="job-list-item__info b-clearfix b-content"]')
for each_job_content in job_content:
    result = each_job_content.text
    # print(result)
    job_content_list.append(result)
print(len(job_content_list))
# Out:
# 20

# %%
# 各職缺網址
for each_url in article_url:
    result = 'https:' + each_url["href"]
    # print(result)
    article_url_list.append(result)
print(len(article_url_list))
# Out:
# 20

# %%
for each_job_content in job_content:
    print(each_job_content.text)
# Out:
# 助專案架構設計
#
# 職務需求：
# 1.熟悉 Flask 框架
# 2.熟悉 Git 開發管理專案
# 3.熟悉 SQL 及 MongoDB 資料庫
# 4.熟悉 ML 相關知識
# 5.熟悉Python程式語言，包含Pandas, Numpy, Sklearn,
# 技術資格：具備以下開發經驗與技術
# 1. 熟悉Scikit-learn/Yolo/OpenCV/TensorFlow框架
# 2. 熟悉CI/CD
# 3. 具系統整合者經驗者佳
# 4. 有參與AI專案/競賽經驗者佳
# 5. 精通 Python 程式設計
#
# 其
#
#
# 部門A
# 1. Linux / Windows設定安裝，自動化測試
# 2. 英文書寫溝通
# 3. 熟悉Python、C/C++、 C# (加分)、.Net frmework、Net Core
# 4. 測試工具Python pytest
# 嗨～～哈囉～
#
# 你是本公司要找的後端工程師高手嗎?
# 就是你！別懷疑！！徵的就是你～
# 本公司需要有在Python數據分析 實務上2-3年以上開發經驗的你唷～
#
# 此職缺的職務內容有：
#
# • 負責各營運產品的模型運用、調整、流程優化
# • 開發新專案的原
# 1. 負責資料平臺/運營平臺等專案的開發
# 2. 負責遊戲產品的web服務開發
#
#
# 必備條件(含技術工具、語言及工作經歷)：
# 1.熟練掌握Python3，有3年以上python服務端開發經驗
# 2.熟悉Python語言以及常用的類庫，有Web研發相關
# #工作內容
# 1. 以Python開發自動化測試的流程和腳本語言
# 2. 使用Raspberry Pi自動控制繼電器開關，並於Linux Ubuntu進行SSD Firmware驗證
# 3. Automation環境架設、維護、基本故障排除等（含樹莓派
# 統設備，使用的技術以 Python 為主，需要熟練 Linux/Git 操作，具體技能如下：
#
# 1.熟悉 Python 程式語言
# 2.熟練 Linux 命令列操作
# 3.熟悉git操作
# 4.具備團隊精神、良好的表達和溝通能力，樂於與團隊溝通
# 5.科系
# 工作內容
# - Python 後端程式、服務開發、API建置
# - 資料庫建置與規劃，瞭解 SQL 語法(MS SQL、MySQL、PostgerSQL)
# - 資料結構規劃
# - 透過 GitLab 執行合作開發和產品版本管理
# - 參與新專案與產品設計
# ]
# 1. 具備程式撰寫能力，能以Python進行資料處理或編寫後端API
# 2. 具備相關 Django framework開發經驗更好
# 3. 對於資料庫系統與其語法有瞭解(包含MySQL )
# 4. 對於Linux系統基本操作與git有經驗者為佳
# 5
# Python programmer/data scientist for quantitative trading
# Seeking junior multi-asset strategist/developer/data scientist
# Life is short, you need Python.
#
# 這個職務需要與整個產品研發團隊密集溝通及合作，負責完成主要產品所需的各式內部需求，以 Python 開發，維護 Django Template 的專案。
# 主要工作 Python
# 1. 負責搭建和持續改進項目平台
# 2. 負責數據分析平台開發與優化
# 3. 負責web服務器開發
#
#
# 必備條件(含技術工具、語言及工作經歷)：
# - 資訊相關科系大學以上學歷、至少1年的後端Web開發經驗
# - 熟悉Python語言以及常用的類庫，有
# 1. 負責軟體之分析、設計以及程式撰寫。
# 2. 規劃執行軟體架構及模組之設計，並控管軟體設計進度。
# 3. 進行軟體之測試與修改。
# 4. 規劃、執行與維護量產的產品。
# 5. 協助研發軟體新技術與新工具。
# 6. 管控軟體開發成本。
#
# 1. 主要使用Java、Python程式語言。
# 2. 模擬、修正現有系統程式。
# 3. 設計、開發新的程式及前端介面。
# 4. 操作手冊、技術文件撰寫。
# 5. 單元測試、整合測試、資安檢測與修復。
#
# ※工作待遇：將依學經歷進行敘薪。
#  code review, 共同成長
#
#
# -----具備條件-----
# 1. 熟悉 Python 或 Node.js
# 2. 熟悉 MongoDB
# 3. 熟悉 AWS 服務與操作
# 4. 熟悉 GraphQL 或 RESTful API
# 5. 熟悉以下工具
#  RDBMS and SQL.
# * Familiar with Python.
#
# PREFERRED QUALIFICATIONS
# * Experience in graph database and graphic algorithm would be
# 1. 開發網站(如Django framework)
# 2. 系統串連，如以ORM連結Relational Database (POSTgrres SQL) 或Haystack 連結 SolrCloud
# 3. 需熟悉OOP及MVC觀念及運用。
# 4.  開發Restful API。
# 5. 熟悉版本控制及Unit Testing技術。
# 研究者精神
# + 能屈能伸、擁抱變化的開發者精神
#
# ### 希望你會 ###
# 1. 熟悉Python、任一Python Web Framework(Flask, Django…etc)
# 2. 熟悉使用ORM(SQLAlchamy…etc)
# 3. 熟悉
# 1.悉Python語言以及常用的類庫，有Web研發相關知識，熟悉至少一個Python Web框架(如Flask/Django/Tornado)
# 2.熟悉開發 Restful API、Vue.js框架
# 3.熟悉MS SQL、MySQL、
# 發者精神
#
# ### 希望你會 ###
# 1. 熟悉Python、任一Python Web Framework(Flask, Django…etc)
# 2. 熟悉使用ORM(SQLAlchamy…etc)
# 3. 熟悉物件導向程式設計、結構化程式設計
# 4.

# %%
# 找關鍵字python、javascript、java、mysql......
for each_job_content in job_content:
    # re.IGNORECASE忽略大小寫
    if re.search("python",each_job_content.text,re.IGNORECASE):
        python_list.append("1")
    else:
        python_list.append("0")
for each_job_content in job_content:
    if re.search("javascript",each_job_content.text,re.IGNORECASE):
        js_list.append("1")
    else:
        js_list.append("0")
for each_job_content in job_content:
    if re.search("java",each_job_content.text,re.IGNORECASE):
        java_list.append("1")
    else:
        java_list.append("0")
for each_job_content in job_content:
    if re.search("mysql",each_job_content.text,re.IGNORECASE):
        mysql_list.append("1")
    else:
        mysql_list.append("0")
for each_job_content in job_content:
    if re.search("mongodb",each_job_content.text,re.IGNORECASE):
        mongodb_list.append("1")
    else:
        mongodb_list.append("0")
for each_job_content in job_content:
    if re.search("sql",each_job_content.text,re.IGNORECASE):
        sql_list.append("1")
    else:
        sql_list.append("0")
for each_job_content in job_content:
    if re.search("nosql",each_job_content.text,re.IGNORECASE):
        nosql_list.append("1")
    else:
        nosql_list.append("0")

# %%
df = pd.DataFrame(columns=["company_name"],data=company_list)
df["jobname"] = jobname_list
df["job_content"] = job_content_list
df["url"] = article_url_list
df["Python"] = python_list
df["JavaScript"] = js_list
df["Java"] = java_list
df["MySQL"] = mysql_list
df["mongodb"] = mongodb_list
df["sql"] = sql_list
df["nosql"] = nosql_list
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 df = pd.DataFrame(columns=["company_name"],data=company_list)
#       2 df["jobname"] = jobname_list
# ----> 3 df["job_content"] = job_content_list
#       4 df["url"] = article_url_list
#       5 df["Python"] = python_list
#
# File /opt/anaconda3/envs/ds_py39/lib/python3.9/site-packages/pandas/core/frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File /opt/anaconda3/envs/ds_py39/lib/python3.9/site-packages/pandas/core/frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File /opt/anaconda3/envs/ds_py39/lib/python3.9/site-packages/pandas/core/frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
# -> 4915     com.require_length_match(value, self.index)
#    4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File /opt/anaconda3/envs/ds_py39/lib/python3.9/site-packages/pandas/core/common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (20) does not match length of index (40)

# %%
# print(jobname_list)
print(len(jobname_list))
# Out:
# 40

# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import random

https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=Python%20&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&area=6001001010&order=15&asc=0&page=4&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1

dataStr = """ro: 0
kwop: 7
keyword: Python
expansionType: area,spec,com,job,wf,wktm
area: 6001001010
order: 15
asc: 0
page: 10
mode: s
jobsource: 2018indexpoc
langFlag: 0
langStatus: 0
recommendJob: 1
hotJob: 1"""
data = {r.split(": ")[0]: r.split(": ")[1] for r in dataStr.split("\n")}

company_list = []
jobname_list = []
job_content_list = []
article_url_list = []
python_list = []
js_list = []
java_list = []
mysql_list = []
mongodb_list = []
sql_list = []
nosql_list = []

# 抓不同頁
for i in range(1,3):
    url = f"https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=Python%20&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&area=6001001010&order=15&asc=0&page=4&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1"
    headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"}
    res = requests.post(url, headers=headers, data=data)
    soup = BeautifulSoup(res.text, 'html.parser')
    # 公司名稱
    company = soup.select('ul[class="b-list-inline b-clearfix"]')
    for each_company in company:
        result = each_company.a["title"].split("：")[1].split("\n")[0]
        company_list.append(result)
    # 職稱
    article_url = soup.select('a[class="js-job-link"]')
    for each_jobname in article_url:
        result = each_jobname.text
        jobname_list.append(result)
    # 工作內容
    job_content = soup.select('p[class="job-list-item__info b-clearfix b-content"]')
    for each_job_content in job_content:
        result = each_job_content.text
        job_content_list.append(result)
    # 各職缺網址
    for each_url in article_url:
        result = 'https:' + each_url["href"]
        article_url_list.append(result)
    # 找關鍵字python、javascript、java、mysql......
    for each_job_content in job_content:
        if re.search("python",each_job_content.text,re.IGNORECASE):
            python_list.append("1")
        else:
            python_list.append("0")
    for each_job_content in job_content:
        if re.search("javascript",each_job_content.text,re.IGNORECASE):
            js_list.append("1")
        else:
            js_list.append("0")
    for each_job_content in job_content:
        if re.search("java",each_job_content.text,re.IGNORECASE):
            java_list.append("1")
        else:
            java_list.append("0")
    for each_job_content in job_content:
        if re.search("mysql",each_job_content.text,re.IGNORECASE):
            mysql_list.append("1")
        else:
            mysql_list.append("0")
    for each_job_content in job_content:
        if re.search("mongodb",each_job_content.text,re.IGNORECASE):
            mongodb_list.append("1")
        else:
            mongodb_list.append("0")
    for each_job_content in job_content:
        if re.search("sql",each_job_content.text,re.IGNORECASE):
            sql_list.append("1")
        else:
            sql_list.append("0")
    for each_job_content in job_content:
        if re.search("nosql",each_job_content.text,re.IGNORECASE):
            nosql_list.append("1")
        else:
            nosql_list.append("0")
    sleep_time = random.randint(3,10)
    print("sleep time: %s sec"%(sleep_time))
    time.sleep(sleep_time)
            
    
    
df = pd.DataFrame(columns=["company_name"],data=company_list)
df["jobname"] = jobname_list
df["url"] = article_url_list
df["Python"] = python_list
df["JavaScript"] = js_list
df["Java"] = java_list
df["MySQL"] = mysql_list
df["mongodb"] = mongodb_list
df["sql"] = sql_list
df["nosql"] = nosql_list
df["job_content"] = job_content_list
# df.to_excel("./104job.xlsx", index=False, encoding="utf-8-sig")
df
# 可以把df秀出來
# Out:
# sleep time: 7 sec
# sleep time: 10 sec
#                                          company_name  \
# 0                                          智聯服務股份有限公司
# 1                                   新加坡商威兆科技有限公司台灣分公司
# 2                                            偉欣資訊有限公司
# 3            PHOENIX TECHNOLOGIES INC_美商費尼克斯有限公司台灣分公司
# 4                                          精誠資訊股份有限公司
# 5                                        創源生物科技股份有限公司
# 6                                          巨量移動科技有限公司
# 7                                             萌萌達有限公司
# 8                                            數字自由有限公司
# 9                                           立普思股份有限公司
# 10                                         點映科技股份有限公司
# 11                               國泰世華商業銀行股份有限公司_人力資源部
# 12                                           雲策數據有限公司
# 13                                           數字自由有限公司
# 14                                        台灣特斯拉汽車有限公司
# 15                                  璞園建築團隊_樸園廣告股份有限公司
# 16                                         全科科技股份有限公司
# 17                                         景翊科技股份有限公司
# 18                                       悠由數據應用股份有限公司
# 19                                         安富科技股份有限公司
# 20           PHOENIX TECHNOLOGIES INC_美商費尼克斯有限公司台灣分公司
# 21                                       台灣資料科學股份有限公司
# 22                                         木荷科技股份有限公司
# 23                                          立普思股份有限公司
# 24                         台灣羅德史瓦茲有限公司(ROHDE&SCHWARZ)
# 25                                           創順科技有限公司
# 26                 CATCHPLAY_英屬蓋曼群島商威望國際娛樂股份有限公司台灣分公司
# 27                                           創順科技有限公司
# 28                                         智聯服務股份有限公司
# 29  特力集團＿HOLA＿HOLA CASA＿HOLA Petite＿Crate&Barrel＿特...
# 30                                  新加坡商威兆科技有限公司台灣分公司
# 31                                           偉欣資訊有限公司
# 32           PHOENIX TECHNOLOGIES INC_美商費尼克斯有限公司台灣分公司
# 33                                         精誠資訊股份有限公司
# 34                                       創源生物科技股份有限公司
# 35                                         巨量移動科技有限公司
# 36                                            萌萌達有限公司
# 37                                           數字自由有限公司
# 38                                         點映科技股份有限公司
# 39                               國泰世華商業銀行股份有限公司_人力資源部
#
#                                               jobname  \
# 0                             【IT】手機測試工程師(台北)(內湖科學園區)
# 1                            IT Developer ( IT 程式設計師)
# 2                                           駐點開發程式設計師
# 3                      Software Designer (Tools Team)
# 4                      【AI+】ChatBot開發工程師(全端) - 2IR100
# 5                                          次世代定序資訊工程師
# 6                                               AI工程師
# 7                  【新創公司徵伙伴】初階運維助理工程師 (歡迎相關科系應屆畢業生應徵)
# 8          資深雲端運維工程師 Senior Cloud Operations Engineer
# 9                                    Optical Engineer
# 10                                            系統運維工程師
# 11              【資訊專才】自動化測試工程師／QA Automation Engineer
# 12                                            軟體測試工程師
# 13  測試工程師 Junior Software Quality Assurance Engine...
# 14  Advanced Driver Assistance Systems (ADAS) Test...
# 15                                       璞園建築團隊 軟體工程師
# 16                                          機器學習應用工程師
# 17                                        工程師 - 數位創新部
# 18                                              資料工程師
# 19                                       [台北]音訊演算法工程師
# 20                   Software Designer (Silicon Team)
# 21                                            全端助理工程師
# 22                          AWS Cloud DevOps Engineer
# 23                                 Algorithm Engineer
# 24                        3511 - Application Engineer
# 25                           Junior Back-End Engineer
# 26                                    Product Analyst
# 27                           Senior Back-End Engineer
# 28                            【IT】手機測試工程師(台北)(內湖科學園區)
# 29                       (內湖總公司) 資料科學家 Data Scientist
# 30                           IT Developer ( IT 程式設計師)
# 31                                          駐點開發程式設計師
# 32                     Software Designer (Tools Team)
# 33                     【AI+】ChatBot開發工程師(全端) - 2IR100
# 34                                         次世代定序資訊工程師
# 35                                              AI工程師
# 36                 【新創公司徵伙伴】初階運維助理工程師 (歡迎相關科系應屆畢業生應徵)
# 37         資深雲端運維工程師 Senior Cloud Operations Engineer
# 38                                            系統運維工程師
# 39              【資訊專才】自動化測試工程師／QA Automation Engineer
#
#                                                   url Python JavaScript Java  \
# 0   https://www.104.com.tw/job/7vzyw?jobsource=jol...      1          0    1
# 1   https://www.104.com.tw/job/7naey?jobsource=jol...      1          1    1
# 2   https://www.104.com.tw/job/5xu4w?jobsource=jol...      1          0    1
# 3   https://www.104.com.tw/job/7thth?jobsource=jol...      1          0    0
# 4   https://www.104.com.tw/job/7jjjz?jobsource=jol...      0          0    0
# 5   https://www.104.com.tw/job/7qjpx?jobsource=jol...      1          0    0
# 6   https://www.104.com.tw/job/7t50v?jobsource=jol...      0          0    0
# 7   https://www.104.com.tw/job/7ebn1?jobsource=jol...      0          0    0
# 8   https://www.104.com.tw/job/7lf4x?jobsource=jol...      1          0    0
# 9   https://www.104.com.tw/job/7nxj6?jobsource=jol...      1          0    0
# 10  https://www.104.com.tw/job/7w6m6?jobsource=jol...      1          0    0
# 11  https://www.104.com.tw/job/4hrz5?jobsource=jol...      0          0    0
# 12  https://www.104.com.tw/job/7gkzt?jobsource=jol...      0          0    0
# 13  https://www.104.com.tw/job/7qrt1?jobsource=jol...      0          0    0
# 14  https://www.104.com.tw/job/7w3td?jobsource=jol...      0          0    0
# 15  https://www.104.com.tw/job/7uaox?jobsource=jol...      0          0    0
# 16  https://www.104.com.tw/job/7gdqv?jobsource=jol...      1          0    0
# 17  https://www.104.com.tw/job/7vxd6?jobsource=jol...      1          0    0
# 18  https://www.104.com.tw/job/7dmcp?jobsource=jol...      1          1    1
# 19  https://www.104.com.tw/job/7bsx3?jobsource=jol...      1          0    0
# 20  https://www.104.com.tw/job/7bc54?jobsource=jol...      0          0    0
# 21  https://www.104.com.tw/job/7ofkj?jobsource=jol...      1          0    0
# 22  https://www.104.com.tw/job/7sf25?jobsource=jol...      1          0    0
# 23  https://www.104.com.tw/job/73y1k?jobsource=jol...      1          0    0
# 24  https://www.104.com.tw/job/7e8au?jobsource=jol...      0          0    0
# 25  https://www.104.com.tw/job/7t78m?jobsource=jol...      1          0    0
# 26  https://www.104.com.tw/job/7lv09?jobsource=jol...      0          0    0
# 27  https://www.104.com.tw/job/7t78s?jobsource=jol...      1          0    0
# 28  https://www.104.com.tw/job/7vzyw?jobsource=jol...      1          0    1
# 29  https://www.104.com.tw/job/7w58r?jobsource=jol...      0          0    0
# 30  https://www.104.com.tw/job/7naey?jobsource=jol...      1          1    1
# 31  https://www.104.com.tw/job/5xu4w?jobsource=jol...      1          0    1
# 32  https://www.104.com.tw/job/7thth?jobsource=jol...      1          0    0
# 33  https://www.104.com.tw/job/7jjjz?jobsource=jol...      0          0    0
# 34  https://www.104.com.tw/job/7qjpx?jobsource=jol...      1          0    0
# 35  https://www.104.com.tw/job/7t50v?jobsource=jol...      0          0    0
# 36  https://www.104.com.tw/job/7ebn1?jobsource=jol...      0          0    0
# 37  https://www.104.com.tw/job/7lf4x?jobsource=jol...      1          0    0
# 38  https://www.104.com.tw/job/7w6m6?jobsource=jol...      1          0    0
# 39  https://www.104.com.tw/job/4hrz5?jobsource=jol...      0          0    0
#
#    MySQL mongodb sql nosql                                        job_content
# 0      0       0   0     0  1. 手機效能測試 (場測及儀器測試)\n2. 發展自動化系統及改善測試流程\n3. 測試結...
# 1      0       0   0     0  \n\n\n【具備技能】\n1. 至少三年相關工作經驗\n2. 熟Restful API、J...
# 2      0       0   0     0  Net、Java、PHP、Python、前端UI/UX、APP或QA、MIS等，具備專業證照...
# 3      0       0   0     0   internal teams or external customers.\n\nRequ...
# 4      0       0   0     0  1.負責開發對話機器人應用，包含對話流程，核心演算與相關應用。需與團隊(UX、PM、產品企劃...
# 5      0       0   0     0  TCGA、CCLE、LINCS、GWAS目錄等數據庫和平台 \n4. 具R、Shell或py...
# 6      0       0   0     0  1. 開發生理訊號判讀模型。\n2. 收集以及處理訓練訊號。 \n3. MLOPS模組開發與...
# 7      0       0   0     0  在台灣有能力的工作伙伴不少，\n看到我們徵才資訊的你\n是否有種在公司一年一年無趣地度過而無...
# 8      1       0   1     0  Grafana、Prometheus等監控工具\n6. 熟悉 Git相關等版控工具\n7. ...
# 9      0       0   0     0   sensing, measurement, or metrology systems \n...
# 10     0       0   0     0                                           python)。
# 11     0       0   0     0  1. 規劃、建置與維護自動化測試相關平台。\n2. 維護自動化測試相關工具程式。\n3. 透...
# 12     0       0   0     0  工作內容：\n1、進行功能測試\n2、驗證系統功能，進行整合測試\n3、規劃測試計劃，設計並...
# 13     1       1   1     0  ● 工作內容：\n1. 協同專案需求，參與需求分析、建立測試計劃、專案驗收計劃等工作。\n2...
# 14     0       0   0     0  We are looking for a highly motivated individu...
# 15     0       0   0     0  1.現有應用系統功能新增與維護。\n2.售服系統上線後功能修改與維護。\n3.房銷與人事系統...
# 16     0       0   0     0  工作內容：\n將機器學習應用移植到Edge AI SoC或MCU上。包含\n- 依照需求開發...
# 17     0       0   0     0  料、正確設置投影、篩選資料、環域分析等)\n2.會使用 R 或 Python 進行資料清理、...
# 18     0       0   1     0  資料工程師\n\n【工作內容】\n1. 數據分析、應用之相關程式(R)開發\n2. API、...
# 19     0       0   0     0  器學習演算法架構，如 DNN、CNN、RNN、LSTM等，來實現不同音訊處理演算法應用。\n...
# 20     0       0   0     0  - Designing and developing BIOS firmware to su...
# 21     0       0   1     1  語言技能，熟悉任一種: Python, React.js\n• OOP, Multi-thr...
# 22     0       0   0     0   Experience with 1-3 years of common script la...
# 23     0       0   0     0   or C++ or Python.\n•\tStrong self-motivation ...
# 24     0       0   0     0  - Responsible for RF test and measurement appl...
# 25     0       0   0     0   Familiarity with Python and any of its web fr...
# 26     0       0   0     0  **RESPONSIBILITIES**\n1.\tDefine what needs to...
# 27     0       0   0     0   the critical system components.\n\n- Must to ...
# 28     0       0   0     0  1. 手機效能測試 (場測及儀器測試)\n2. 發展自動化系統及改善測試流程\n3. 測試結...
# 29     0       0   0     0  若您熱愛數據分析、且對機器學習導入零售行業的應用富有熱情，你就是我們要徵的人才! \n\n我...
# 30     0       0   0     0  \n\n\n【具備技能】\n1. 至少三年相關工作經驗\n2. 熟Restful API、J...
# 31     0       0   0     0  Net、Java、PHP、Python、前端UI/UX、APP或QA、MIS等，具備專業證照...
# 32     0       0   0     0   internal teams or external customers.\n\nRequ...
# 33     0       0   0     0  1.負責開發對話機器人應用，包含對話流程，核心演算與相關應用。需與團隊(UX、PM、產品企劃...
# 34     0       0   0     0  TCGA、CCLE、LINCS、GWAS目錄等數據庫和平台 \n4. 具R、Shell或py...
# 35     0       0   0     0  1. 開發生理訊號判讀模型。\n2. 收集以及處理訓練訊號。 \n3. MLOPS模組開發與...
# 36     0       0   0     0  在台灣有能力的工作伙伴不少，\n看到我們徵才資訊的你\n是否有種在公司一年一年無趣地度過而無...
# 37     1       0   1     0  Grafana、Prometheus等監控工具\n6. 熟悉 Git相關等版控工具\n7. ...
# 38     0       0   0     0                                           python)。
# 39     0       0   0     0  1. 規劃、建置與維護自動化測試相關平台。\n2. 維護自動化測試相關工具程式。\n3. 透...

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
